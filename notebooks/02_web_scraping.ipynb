# %% [markdown]
# # 02 Web Scraping - Launch Pads and Landing Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'lxml')
# scraping would go here
